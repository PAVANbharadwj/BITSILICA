# %%
#1.cal sum and prod in a single line
n = 10
m = 20
Sum,prod = n+m,n*m
print(Sum,prod)
# Out:
# 30 200

# %%
#2.true if odd
n = 25
result = (n%2==1)
print(result)
# Out:
# True

# %%
#3.last digit
n = int(input())
last_d = n%10
print(last_d)
# Out:
# 545
# 5

# %%
#4.celsius to farhenheit
C = float(input("celcius:"))
f = (9/5)*C + 32
print(f)
# Out:
# celcius:35.5
# 95.9

# %%
#5.incrememt
n = int(input())
n += 1
print(n)
# Out:
# 5
# 6

# %%
#6.avg of two
a,b = 10,20
avg = (a+b)/2
print(avg)
# Out:
# 15.0

# %%
#7.diff of two
a,b= 10,20
print(a-b)
# Out:
# -10

# %%
#8.doule its value
a = 10
d = 10*2
print(d)
# Out:
# 20

# %%
#9.square of num
n = 20
sq = n**2
print(sq)
# Out:
# 400

# %%
#10.divisible by 5
n = 20
res = (n%5==0)
print(res)
# Out:
# True
